# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def fit_linear_regression(X, y):
    Xt = X.T
    XtX = Xt @ X
    XtY = Xt @ y
    
    theta = np.linalg.solve(XtX, XtY)
    
    return theta
